# %% [markdown]
# Creating Stream Channel Data Frame

# %%
# Import dependencies and store twitch client id
import json
import requests
import pandas as pd
from pprint import pprint
import time
import datetime

client_id = "t0md9tc73ojytjz65vuf0bd1yfyd39"

# %%
# Initiliaze url and create empty string to store top game names
game_base_url = f"https://api.twitch.tv/kraken/games/top/?client_id={client_id}&limit=30"
top_game_data = requests.get(game_base_url).json()
games = []

# %%
# Create for loop and create list of top 25 games
for i in range(0,25):
    game = top_game_data['top'][i]['game']['name']
    games.append(game)

# %%
# Use list of top game names from previous API request to search top 10 streams per game
stream_base_url = f"https://api.twitch.tv/kraken/streams/?client_id={client_id}&limit=15&game="
index = 0
display_names = []
ranks = []
viewers_list = []
followers_list = []
total_channel_views_list = []
timestamps = []
game_names = []

for game in games:
    stream_url = stream_base_url + game
    top_10_stream_data = requests.get(stream_url).json()

    for j in range(0,10):
        
        try:
            display_name = top_10_stream_data['streams'][j]['channel']['display_name']
            display_names.append(display_name)
            rank = j + 1
        
            ranks.append(rank)
        
            game_names.append(game)
        
            num_viewers = top_10_stream_data['streams'][j]['viewers']
            viewers_list.append(num_viewers)
        
            num_followers = top_10_stream_data['streams'][j]['channel']['followers']
            followers_list.append(num_followers)
        
            total_channel_views = top_10_stream_data['streams'][j]['channel']['views']
            total_channel_views_list.append(total_channel_views)
            
            unix_time = time.time()
            timestamp = datetime.datetime.fromtimestamp(unix_time).strftime('%Y-%m-%d %H:%M')
            timestamps.append(timestamp)
        except: IndexError

# %%
stream_df = pd.DataFrame({"Timestamp": timestamps,
                         "Rank": ranks,
                         "Display Name": display_names,
                         "Game Title": game_names,
                         "Viewers": viewers_list,
                         "Channel Followers": followers_list,
                         "Total Channel Views": total_channel_views_list})
stream_df
# Out:
#             Timestamp  Rank      Display Name                Game Title  \
# 0    2018-10-03 21:58     1             Ninja                  Fortnite
# 1    2018-10-03 21:58     2              Tfue                  Fortnite
# 2    2018-10-03 21:58     3       TSM_Daequan                  Fortnite
# 3    2018-10-03 21:58     4         NICKMERCS                  Fortnite
# 4    2018-10-03 21:58     5      TimTheTatman                  Fortnite
# 5    2018-10-03 21:58     6              zEkO                  Fortnite
# 6    2018-10-03 21:58     7          TSM_Myth                  Fortnite
# 7    2018-10-03 21:58     8           Cizzorz                  Fortnite
# 8    2018-10-03 21:58     9             POACH                  Fortnite
# 9    2018-10-03 21:58    10    SolaryFortnite                  Fortnite
# 10   2018-10-03 21:58     1             jukes         League of Legends
# 11   2018-10-03 21:58     2           Froggen         League of Legends
# 12   2018-10-03 21:58     3             Rakin         League of Legends
# 13   2018-10-03 21:58     4            Voyboy         League of Legends
# 14   2018-10-03 21:58     5          tarzaned         League of Legends
# 15   2018-10-03 21:58     6           Trick2g         League of Legends
# 16   2018-10-03 21:58     7        VaporaDark         League of Legends
# 17   2018-10-03 21:58     8            Scarra         League of Legends
# 18   2018-10-03 21:58     9            Solary         League of Legends
# 19   2018-10-03 21:58    10          LLStylez         League of Legends
# 20   2018-10-03 21:58     1            shroud  Assassin's Creed Odyssey
# 21   2018-10-03 21:58     2              YoDa  Assassin's Creed Odyssey
# 22   2018-10-03 21:58     3        fextralife  Assassin's Creed Odyssey
# 23   2018-10-03 21:58     4               풍월량  Assassin's Creed Odyssey
# 24   2018-10-03 21:58     5        DansGaming  Assassin's Creed Odyssey
# 25   2018-10-03 21:58     6              서새봄냥  Assassin's Creed Odyssey
# 26   2018-10-03 21:58     7            JoshOG  Assassin's Creed Odyssey
# 27   2018-10-03 21:58     8            itmeJP  Assassin's Creed Odyssey
# 28   2018-10-03 21:58     9          Agraelus  Assassin's Creed Odyssey
# 29   2018-10-03 21:58    10    giganterichard  Assassin's Creed Odyssey
