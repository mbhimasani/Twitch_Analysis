# %% [markdown]
# Creating Stream Channel Data Frame

# %%
# Import dependencies and store twitch client id
import json
import requests
import pandas as pd
from pprint import pprint
import time
import datetime
import numpy as np

client_id = "t0md9tc73ojytjz65vuf0bd1yfyd39"

# %%
# Initiliaze url and create empty string to store top game names
game_base_url = f"https://api.twitch.tv/kraken/games/top/?client_id={client_id}&limit=30"
top_game_data = requests.get(game_base_url).json()
games = []

# %%
# Create for loop and create list of top 25 games
for i in range(0,25):
    game = top_game_data['top'][i]['game']['name']
    games.append(game)

# %%
# Use list of top game names from previous API request to search top 10 streams per game
stream_base_url = f"https://api.twitch.tv/kraken/streams/?client_id={client_id}&limit=15&game="
display_names = []
ranks = []
viewers_list = []
followers_list = []
total_channel_views_list = []
timestamps = []
game_names = []

for game in games:
    stream_url = stream_base_url + game
    top_10_stream_data = requests.get(stream_url).json()

    for j in range(0,10):
        
        try:
            display_name = top_10_stream_data['streams'][j]['channel']['display_name']
            display_names.append(display_name)
            rank = j + 1
        
            ranks.append(rank)
        
            game_names.append(game)
        
            num_viewers = top_10_stream_data['streams'][j]['viewers']
            viewers_list.append(num_viewers)
        
            num_followers = top_10_stream_data['streams'][j]['channel']['followers']
            followers_list.append(num_followers)
        
            total_channel_views = top_10_stream_data['streams'][j]['channel']['views']
            total_channel_views_list.append(total_channel_views)
            
            unix_time = time.time()
            timestamp = datetime.datetime.fromtimestamp(unix_time).strftime('%Y-%m-%d %H:%M')                
            timestamps.append(timestamp)
    
        except: IndexError

# %%
stream_df = pd.DataFrame({'Timestamp': timestamps, 
                          'Game Title': game_names,
                          'Rank': ranks,
                          'Display Name': display_names,
                          'Viewers': viewers_list,
                          'Channel Followers': followers_list,
                          'Total Channel Views': total_channel_views_list})
stream_df
# Out:
#             Timestamp         Game Title  Rank      Display Name  Viewers  \
# 0    2018-10-04 19:00           Fortnite     1          SypherPK    21092
# 1    2018-10-04 19:00           Fortnite     2         NICKMERCS    12605
# 2    2018-10-04 19:00           Fortnite     3          pokimane    12278
# 3    2018-10-04 19:00           Fortnite     4          TSM_Myth    11614
# 4    2018-10-04 19:00           Fortnite     5           cloakzy     9179
# 5    2018-10-04 19:00           Fortnite     6           Cizzorz     7001
# 6    2018-10-04 19:00           Fortnite     7             POACH     4848
# 7    2018-10-04 19:00           Fortnite     8       RakanooLive     3708
# 8    2018-10-04 19:00           Fortnite     9           GubbaTV     2418
# 9    2018-10-04 19:00           Fortnite    10    SolaryFortnite     2301
# 10   2018-10-04 19:00  League of Legends     1        Riot Games    28989
# 11   2018-10-04 19:00  League of Legends     2         loltyler1    17657
# 12   2018-10-04 19:00  League of Legends     3             jukes    16430
# 13   2018-10-04 19:00  League of Legends     4          imaqtpie     8454
# 14   2018-10-04 19:00  League of Legends     5   RiotGamesBrazil     5532
# 15   2018-10-04 19:00  League of Legends     6         ElmiilloR     3924
# 16   2018-10-04 19:00  League of Legends     7          Shiphtur     3671
# 17   2018-10-04 19:00  League of Legends     8              Levo     2859
# 18   2018-10-04 19:00  League of Legends     9          LLStylez     2533
# 19   2018-10-04 19:00  League of Legends    10            Solary     2454
# 20   2018-10-04 19:00  World of Warcraft     1           Reckful    19840
# 21   2018-10-04 19:00  World of Warcraft     2          Hotted89    11157
# 22   2018-10-04 19:00  World of Warcraft     3             cdewx     3039
# 23   2018-10-04 19:00  World of Warcraft     4        Pikabooirl     2455
# 24   2018-10-04 19:00  World of Warcraft     5        Drjayfisto     2052
# 25   2018-10-04 19:00  World of Warcraft     6           W_Lapin     1182
# 26   2018-10-04 19:00  World of Warcraft     7         Hydramist     1176
# 27   2018-10-04 19:00  World of Warcraft     8             jdotb     1110
# 28   2018-10-04 19:00  World of Warcraft     9       ThaldrinLol     1078
# 29   2018-10-04 19:00  World of Warcraft    10      ayo_________      976
# ..                ...                ...   ...               ...      ...
# 220  2018-10-04 19:00    Ring Of Elysium     1           JERICHO     2283
# 221  2018-10-04 19:00    Ring Of Elysium     2              vsnz     1878
# 222  2018-10-04 19:00    Ring Of Elysium     3      SchviftyFive      287
# 223  2018-10-04 19:00    Ring Of Elysium     4        OyunZadeTV      208
# 224  2018-10-04 19:00    Ring Of Elysium     5          1cePrime      175
# 225  2018-10-04 19:00    Ring Of Elysium     6           rogue22      102
# 226  2018-10-04 19:00    Ring Of Elysium     7     SismannRamboo       97
# 227  2018-10-04 19:00    Ring Of Elysium     8       RFLegendary       95
# 228  2018-10-04 19:00    Ring Of Elysium     9           MaDZeRo       84
# 229  2018-10-04 19:00    Ring Of Elysium    10            Tatted       69
# 230  2018-10-04 19:00      Path of Exile     1           Mathil1     3396
# 231  2018-10-04 19:00      Path of Exile     2    Empyriangaming      622
# 232  2018-10-04 19:00      Path of Exile     3          havoc616      338
# 233  2018-10-04 19:00      Path of Exile     4          TarkeCat      320
# 234  2018-10-04 19:00      Path of Exile     5          jarttu84      292
# 235  2018-10-04 19:00      Path of Exile     6              Pohx      257
# 236  2018-10-04 19:00      Path of Exile     7            Waggle      244
# 237  2018-10-04 19:00      Path of Exile     8           daniels      198
# 238  2018-10-04 19:00      Path of Exile     9    Demigodkinglol      195
# 239  2018-10-04 19:00      Path of Exile    10  PressStartToPaws      130
# 240  2018-10-04 19:00              Poker     1         tonkaaaaP     4209
# 241  2018-10-04 19:00              Poker     2        nolimit_gg      586
# 242  2018-10-04 19:00              Poker     3       kevinmartin      446
# 243  2018-10-04 19:00              Poker     4        runitup247      405
# 244  2018-10-04 19:00              Poker     5       bparispoker      336
# 245  2018-10-04 19:00              Poker     6         minthon19      242
# 246  2018-10-04 19:00              Poker     7          ALLinPav      207
# 247  2018-10-04 19:00              Poker     8     PokerAcademie      181
# 248  2018-10-04 19:00              Poker     9          Fionamed       92
# 249  2018-10-04 19:00              Poker    10    FloPokerFrance       77
#
#      Channel Followers  Total Channel Views
# 0              1535752             23620250
# 1              1713451             32707615
# 2              2250760             45017333
# 3              4359022             60089412
# 4               623182              5881833
# 5              1002244              9707075
# 6               233473              2806360
# 7               356439              2882833
# 8               104356              5181566
# 9               475952             22915304
# 10             3134688           1041163295
# 11             1879641             83957114
# 12              679770             36593837
# 13             2414621            292919703
# 14              565184            112626602
# 15              145109             13867166
# 16              520541             30381580
# 17              474453             26807886
# 18              287808              6367392
# 19              230955             42412235
# 20              775659            100495482
# 21              281022             19065193
# 22              255503             31169454
# 23               91181              4276422
# 24               53878              5413572
# 25              101521             13688672
# 26               85868             13191098
# 27               55017              6372042
# 28              299579             10048276
# 29               24744              1600170
# ..                 ...                  ...
# 220            1056220             23879186
# 221             129682              3289554
# 222             145795              3731448
# 223              44569               915610
# 224              40672              3117973
# 225                660                 2849
# 226               4219                60492
# 227             139558             10601027
# 228               3441                37960
# 229              55239              1164840
# 230             140446             16209174
# 231              48912              3431206
# 232              43094              4919489
# 233              22026              1250436
# 234              35155              2655107
# 235              76597              6313301
# 236              11464               872981
# 237             245642              9508274
# 238              23855               854075
# 239              15713               955528
# 240              88214              7881542
# 241               6091               143158
# 242              76227              4516078
# 243              22644               729182
# 244              29573              1718453
# 245               3636               375330
# 246              32560              1459111
# 247               7611              1408529
# 248              91448              1833545
# 249               1826                43534
#
# [250 rows x 7 columns]

# %%
# Save data frame to csv file with timestamp as name
file_path= time.strftime("%Y-%m-%d-%H-%M-%S")
stream_df.to_csv(file_path, index = False, header = True, sep = ',', encoding = 'utf-8')

# %%
# Out:
# str
