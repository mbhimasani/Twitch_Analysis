# %%
import requests
import json
import meghana_client_ID

# %%
url ="https://api.twitch.tv/kraken/games/top/?client_id="
client_ID = meghana_client_ID.meghana

query_url = url + client_ID
params = {"limit": "50"} #get top 50 games

# %%
games = []
popularity = []
viewers = []
channels = []

# %%
requests.get(query_url, params = params).json() #returns top 50 games
# Out:
# {'_total': 1991,
#  '_links': {'self': 'https://api.twitch.tv/kraken/games/top?limit=50',
#   'next': 'https://api.twitch.tv/kraken/games/top?limit=50&offset=50'},
#  'top': [{'game': {'name': 'Fortnite',
#     'popularity': 264450,
#     '_id': 33214,
#     'giantbomb_id': 37030,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Fortnite-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Fortnite-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Fortnite-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Fortnite-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Fortnite',
#     'locale': ''},
#    'viewers': 259237,
#    'channels': 15563},
#   {'game': {'name': 'League of Legends',
#     'popularity': 129547,
#     '_id': 21779,
#     'giantbomb_id': 24024,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/League%20of%20Legends-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/League%20of%20Legends-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/League%20of%20Legends-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/League%20of%20Legends-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'League of Legends',
#     'locale': ''},
#    'viewers': 130726,
#    'channels': 2554},
#   {'game': {'name': "Assassin's Creed Odyssey",
#     'popularity': 70668,
#     '_id': 506274,
#     'giantbomb_id': 68771,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Assassin%27s%20Creed%20Odyssey-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Assassin%27s%20Creed%20Odyssey-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Assassin%27s%20Creed%20Odyssey-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Assassin%27s%20Creed%20Odyssey-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Assassin%27s%20Creed%20Odyssey-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Assassin%27s%20Creed%20Odyssey-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Assassin%27s%20Creed%20Odyssey-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Assassin%27s%20Creed%20Odyssey-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': "Assassin's Creed Odyssey",
#     'locale': ''},
#    'viewers': 69894,
#    'channels': 491},
#   {'game': {'name': 'Counter-Strike: Global Offensive',
#     'popularity': 59526,
#     '_id': 32399,
#     'giantbomb_id': 36113,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./Counter-Strike:%20Global%20Offensive-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./Counter-Strike:%20Global%20Offensive-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./Counter-Strike:%20Global%20Offensive-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./Counter-Strike:%20Global%20Offensive-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./Counter-Strike:%20Global%20Offensive-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./Counter-Strike:%20Global%20Offensive-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./Counter-Strike:%20Global%20Offensive-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./Counter-Strike:%20Global%20Offensive-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Counter-Strike: Global Offensive',
#     'locale': ''},
#    'viewers': 60665,
#    'channels': 1141},
#   {'game': {'name': 'World of Warcraft',
#     'popularity': 55596,
#     '_id': 18122,
#     'giantbomb_id': 19783,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warcraft-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warcraft-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warcraft-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warcraft-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/World%20of%20Warcraft-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/World%20of%20Warcraft-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/World%20of%20Warcraft-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/World%20of%20Warcraft-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'World of Warcraft',
#     'locale': ''},
#    'viewers': 55165,
#    'channels': 1408},
#   {'game': {'name': 'Just Chatting',
#     'popularity': 46285,
#     '_id': 509658,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Just%20Chatting-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Just%20Chatting-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Just%20Chatting-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Just%20Chatting-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Just Chatting',
#     'locale': ''},
#    'viewers': 47944,
#    'channels': 524},
#   {'game': {'name': 'FIFA 19',
#     'popularity': 40948,
#     '_id': 506103,
#     'giantbomb_id': 68608,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/FIFA%2019-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/FIFA%2019-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/FIFA%2019-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/FIFA%2019-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/FIFA%2019-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/FIFA%2019-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/FIFA%2019-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/FIFA%2019-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'FIFA 19',
#     'locale': ''},
#    'viewers': 41374,
#    'channels': 786},
#   {'game': {'name': 'Dota 2',
#     'popularity': 35800,
#     '_id': 29595,
#     'giantbomb_id': 32887,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Dota%202-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Dota%202-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Dota%202-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Dota%202-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Dota 2',
#     'locale': ''},
#    'viewers': 35960,
#    'channels': 506},
#   {'game': {'name': 'Overwatch',
#     'popularity': 33091,
#     '_id': 488552,
#     'giantbomb_id': 48190,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Overwatch-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Overwatch-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Overwatch-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Overwatch-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Overwatch-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Overwatch-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Overwatch-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Overwatch-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Overwatch',
#     'locale': ''},
#    'viewers': 33352,
#    'channels': 1393},
#   {'game': {'name': 'Grand Theft Auto V',
#     'popularity': 26934,
#     '_id': 32982,
#     'giantbomb_id': 36765,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Grand%20Theft%20Auto%20V-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Grand%20Theft%20Auto%20V-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Grand%20Theft%20Auto%20V-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Grand%20Theft%20Auto%20V-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Grand%20Theft%20Auto%20V-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Grand%20Theft%20Auto%20V-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Grand%20Theft%20Auto%20V-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Grand%20Theft%20Auto%20V-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Grand Theft Auto V',
#     'locale': ''},
#    'viewers': 26422,
#    'channels': 543},
#   {'game': {'name': 'Rocket League',
#     'popularity': 20990,
#     '_id': 30921,
#     'giantbomb_id': 34407,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Rocket%20League-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Rocket%20League-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Rocket%20League-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Rocket%20League-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Rocket%20League-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Rocket%20League-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Rocket%20League-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Rocket%20League-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Rocket League',
#     'locale': ''},
#    'viewers': 22468,
#    'channels': 423},
#   {'game': {'name': "PLAYERUNKNOWN'S BATTLEGROUNDS",
#     'popularity': 21382,
#     '_id': 493057,
#     'giantbomb_id': 54979,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': "PLAYERUNKNOWN'S BATTLEGROUNDS",
#     'locale': ''},
#    'viewers': 21624,
#    'channels': 1486},
#   {'game': {'name': 'Destiny 2',
#     'popularity': 20875,
#     '_id': 497057,
#     'giantbomb_id': 52647,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Destiny%202-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Destiny%202-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Destiny%202-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Destiny%202-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Destiny%202-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Destiny%202-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Destiny%202-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Destiny%202-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Destiny 2',
#     'locale': ''},
#    'viewers': 20390,
#    'channels': 1781},
#   {'game': {'name': 'Ring Of Elysium',
#     'popularity': 23125,
#     '_id': 504954,
#     'giantbomb_id': 67377,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Ring%20Of%20Elysium-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Ring%20Of%20Elysium-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Ring%20Of%20Elysium-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Ring%20Of%20Elysium-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Ring%20Of%20Elysium-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Ring%20Of%20Elysium-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Ring%20Of%20Elysium-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Ring%20Of%20Elysium-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Ring Of Elysium',
#     'locale': ''},
#    'viewers': 18158,
#    'channels': 486},
#   {'game': {'name': 'Hearthstone',
#     'popularity': 17872,
#     '_id': 138585,
#     'giantbomb_id': 42033,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Hearthstone-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Hearthstone-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Hearthstone-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Hearthstone-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Hearthstone-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Hearthstone-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Hearthstone-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Hearthstone-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Hearthstone',
#     'locale': ''},
#    'viewers': 17906,
#    'channels': 192},
#   {'game': {'name': 'Magic: The Gathering',
#     'popularity': 16430,
#     '_id': 2748,
#     'giantbomb_id': 68425,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./Magic:%20The%20Gathering-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./Magic:%20The%20Gathering-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./Magic:%20The%20Gathering-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./Magic:%20The%20Gathering-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./Magic:%20The%20Gathering-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./Magic:%20The%20Gathering-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./Magic:%20The%20Gathering-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./Magic:%20The%20Gathering-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Magic: The Gathering',
#     'locale': ''},
#    'viewers': 16447,
#    'channels': 225},
#   {'game': {'name': 'Always On',
#     'popularity': 13940,
#     '_id': 499973,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Always%20On-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Always%20On-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Always%20On-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Always%20On-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Always%20On-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Always%20On-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Always%20On-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Always%20On-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Always On',
#     'locale': ''},
#    'viewers': 13473,
#    'channels': 18},
#   {'game': {'name': 'MapleStory 2',
#     'popularity': 13271,
#     '_id': 488769,
#     'giantbomb_id': 48529,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/MapleStory%202-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/MapleStory%202-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/MapleStory%202-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/MapleStory%202-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/MapleStory%202-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/MapleStory%202-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/MapleStory%202-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/MapleStory%202-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'MapleStory 2',
#     'locale': ''},
#    'viewers': 13149,
#    'channels': 207},
#   {'game': {'name': 'Casino',
#     'popularity': 11089,
#     '_id': 509576,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Casino-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Casino-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Casino-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Casino-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Casino-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Casino-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Casino-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Casino-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Casino',
#     'locale': ''},
#    'viewers': 11598,
#    'channels': 42},
#   {'game': {'name': 'Dead by Daylight',
#     'popularity': 10895,
#     '_id': 491487,
#     'giantbomb_id': 52693,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Dead%20by%20Daylight-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Dead%20by%20Daylight-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Dead%20by%20Daylight-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Dead%20by%20Daylight-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Dead%20by%20Daylight-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Dead%20by%20Daylight-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Dead%20by%20Daylight-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Dead%20by%20Daylight-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Dead by Daylight',
#     'locale': ''},
#    'viewers': 10817,
#    'channels': 795},
#   {'game': {'name': 'S.T.A.L.K.E.R.: Shadow of Chernobyl',
#     'popularity': 10649,
#     '_id': 10775,
#     'giantbomb_id': 11725,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./S.T.A.L.K.E.R.:%20Shadow%20of%20Chernobyl-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'S.T.A.L.K.E.R.: Shadow of Chernobyl',
#     'locale': ''},
#    'viewers': 10570,
#    'channels': 7},
#   {'game': {'name': 'StarCraft II',
#     'popularity': 9853,
#     '_id': 490422,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft%20II-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft%20II-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft%20II-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft%20II-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/StarCraft%20II-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/StarCraft%20II-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/StarCraft%20II-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/StarCraft%20II-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'StarCraft II',
#     'locale': ''},
#    'viewers': 9976,
#    'channels': 80},
#   {'game': {'name': 'Mega Man 11',
#     'popularity': 9176,
#     '_id': 500560,
#     'giantbomb_id': 63036,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Mega%20Man%2011-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Mega%20Man%2011-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Mega%20Man%2011-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Mega%20Man%2011-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Mega%20Man%2011-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Mega%20Man%2011-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Mega%20Man%2011-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Mega%20Man%2011-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Mega Man 11',
#     'locale': ''},
#    'viewers': 9069,
#    'channels': 285},
#   {'game': {'name': 'Talk Shows & Podcasts',
#     'popularity': 7891,
#     '_id': 417752,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Talk%20Shows%20&%20Podcasts-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Talk%20Shows%20&%20Podcasts-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Talk%20Shows%20&%20Podcasts-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Talk%20Shows%20&%20Podcasts-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Talk%20Shows%20&%20Podcasts-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Talk%20Shows%20&%20Podcasts-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Talk%20Shows%20&%20Podcasts-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Talk%20Shows%20&%20Podcasts-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Talk Shows & Podcasts',
#     'locale': ''},
#    'viewers': 8560,
#    'channels': 144},
#   {'game': {'name': "Tom Clancy's Rainbow Six: Siege",
#     'popularity': 8145,
#     '_id': 460630,
#     'giantbomb_id': 46562,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': "Tom Clancy's Rainbow Six: Siege",
#     'locale': ''},
#    'viewers': 7725,
#    'channels': 1325},
#   {'game': {'name': 'NBA 2K19',
#     'popularity': 7641,
#     '_id': 506383,
#     'giantbomb_id': 68872,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/NBA%202K19-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/NBA%202K19-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/NBA%202K19-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/NBA%202K19-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/NBA%202K19-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/NBA%202K19-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/NBA%202K19-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/NBA%202K19-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'NBA 2K19',
#     'locale': ''},
#    'viewers': 7461,
#    'channels': 518},
#   {'game': {'name': 'Street Fighter V',
#     'popularity': 6024,
#     '_id': 488615,
#     'giantbomb_id': 48320,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Street%20Fighter%20V-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Street%20Fighter%20V-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Street%20Fighter%20V-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Street%20Fighter%20V-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Street%20Fighter%20V-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Street%20Fighter%20V-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Street%20Fighter%20V-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Street%20Fighter%20V-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Street Fighter V',
#     'locale': ''},
#    'viewers': 7083,
#    'channels': 64},
#   {'game': {'name': 'Path of Exile',
#     'popularity': 6518,
#     '_id': 29307,
#     'giantbomb_id': 32562,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Path%20of%20Exile-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Path%20of%20Exile-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Path%20of%20Exile-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Path%20of%20Exile-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Path%20of%20Exile-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Path%20of%20Exile-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Path%20of%20Exile-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Path%20of%20Exile-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Path of Exile',
#     'locale': ''},
#    'viewers': 6506,
#    'channels': 223},
#   {'game': {'name': 'FTL: Faster Than Light',
#     'popularity': 6504,
#     '_id': 33882,
#     'giantbomb_id': 37770,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./FTL:%20Faster%20Than%20Light-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./FTL:%20Faster%20Than%20Light-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./FTL:%20Faster%20Than%20Light-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./FTL:%20Faster%20Than%20Light-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./FTL:%20Faster%20Than%20Light-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./FTL:%20Faster%20Than%20Light-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./FTL:%20Faster%20Than%20Light-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./FTL:%20Faster%20Than%20Light-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'FTL: Faster Than Light',
#     'locale': ''},
#    'viewers': 6398,
#    'channels': 6},
#   {'game': {'name': 'Music & Performing Arts',
#     'popularity': 6186,
#     '_id': 26936,
#     'giantbomb_id': 29887,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Music%20&%20Performing%20Arts-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Music%20&%20Performing%20Arts-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Music%20&%20Performing%20Arts-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Music%20&%20Performing%20Arts-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Music%20&%20Performing%20Arts-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Music%20&%20Performing%20Arts-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Music%20&%20Performing%20Arts-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Music%20&%20Performing%20Arts-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Music & Performing Arts',
#     'locale': ''},
#    'viewers': 6360,
#    'channels': 277},
#   {'game': {'name': 'Old School RuneScape',
#     'popularity': 6011,
#     '_id': 459931,
#     'giantbomb_id': 45837,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Old%20School%20RuneScape-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Old%20School%20RuneScape-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Old%20School%20RuneScape-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Old%20School%20RuneScape-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Old School RuneScape',
#     'locale': ''},
#    'viewers': 6072,
#    'channels': 154},
#   {'game': {'name': 'Heroes of the Storm',
#     'popularity': 5645,
#     '_id': 32959,
#     'giantbomb_id': 36739,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Heroes%20of%20the%20Storm-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Heroes%20of%20the%20Storm-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Heroes%20of%20the%20Storm-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Heroes%20of%20the%20Storm-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Heroes%20of%20the%20Storm-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Heroes%20of%20the%20Storm-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Heroes%20of%20the%20Storm-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Heroes%20of%20the%20Storm-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Heroes of the Storm',
#     'locale': ''},
#    'viewers': 5625,
#    'channels': 173},
#   {'game': {'name': 'Forza Horizon 4',
#     'popularity': 5516,
#     '_id': 506413,
#     'giantbomb_id': 68909,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Forza%20Horizon%204-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Forza%20Horizon%204-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Forza%20Horizon%204-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Forza%20Horizon%204-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Forza%20Horizon%204-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Forza%20Horizon%204-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Forza%20Horizon%204-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Forza%20Horizon%204-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Forza Horizon 4',
#     'locale': ''},
#    'viewers': 5421,
#    'channels': 571},
#   {'game': {'name': 'Battlerite Royale',
#     'popularity': 5494,
#     '_id': 509146,
#     'giantbomb_id': 69841,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Battlerite%20Royale-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Battlerite%20Royale-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Battlerite%20Royale-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Battlerite%20Royale-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Battlerite%20Royale-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Battlerite%20Royale-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Battlerite%20Royale-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Battlerite%20Royale-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Battlerite Royale',
#     'locale': ''},
#    'viewers': 5408,
#    'channels': 149},
#   {'game': {'name': 'LEGO Batman 2: DC Super Heroes',
#     'popularity': 0,
#     '_id': 33104,
#     'giantbomb_id': 36898,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./LEGO%20Batman%202:%20DC%20Super%20Heroes-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'LEGO Batman 2: DC Super Heroes',
#     'locale': ''},
#    'viewers': 5202,
#    'channels': 1},
#   {'game': {'name': 'Escape From Tarkov',
#     'popularity': 5108,
#     '_id': 491931,
#     'giantbomb_id': 53106,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Escape%20From%20Tarkov-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Escape%20From%20Tarkov-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Escape%20From%20Tarkov-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Escape%20From%20Tarkov-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Escape%20From%20Tarkov-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Escape%20From%20Tarkov-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Escape%20From%20Tarkov-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Escape%20From%20Tarkov-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Escape From Tarkov',
#     'locale': ''},
#    'viewers': 4966,
#    'channels': 223},
#   {'game': {'name': 'Minecraft',
#     'popularity': 4579,
#     '_id': 27471,
#     'giantbomb_id': 30475,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Minecraft-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Minecraft-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Minecraft-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Minecraft-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Minecraft-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Minecraft-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Minecraft-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Minecraft-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Minecraft',
#     'locale': ''},
#    'viewers': 4651,
#    'channels': 372},
#   {'game': {'name': 'Dungeons & Dragons',
#     'popularity': 4390,
#     '_id': 509577,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Dungeons%20&%20Dragons-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Dungeons%20&%20Dragons-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Dungeons%20&%20Dragons-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Dungeons%20&%20Dragons-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Dungeons%20&%20Dragons-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Dungeons%20&%20Dragons-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Dungeons%20&%20Dragons-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Dungeons%20&%20Dragons-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Dungeons & Dragons',
#     'locale': ''},
#    'viewers': 4458,
#    'channels': 44},
#   {'game': {'name': 'Prismata',
#     'popularity': 4291,
#     '_id': 488455,
#     'giantbomb_id': 47993,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Prismata-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Prismata-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Prismata-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Prismata-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Prismata-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Prismata-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Prismata-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Prismata-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Prismata',
#     'locale': ''},
#    'viewers': 4299,
#    'channels': 3},
#   {'game': {'name': 'Poker',
#     'popularity': 5555,
#     '_id': 488190,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Poker-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Poker-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Poker-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Poker-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Poker-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Poker-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Poker-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Poker-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Poker',
#     'locale': ''},
#    'viewers': 4298,
#    'channels': 83},
#   {'game': {'name': 'Art',
#     'popularity': 4081,
#     '_id': 509660,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Art-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Art-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Art-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Art-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Art-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Art-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Art-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Art-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Art',
#     'locale': ''},
#    'viewers': 4014,
#    'channels': 299},
#   {'game': {'name': 'Super Seducer 2',
#     'popularity': 5133,
#     '_id': 508749,
#     'giantbomb_id': 69450,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Seducer%202-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Seducer%202-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Seducer%202-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Seducer%202-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Super%20Seducer%202-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Super%20Seducer%202-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Super%20Seducer%202-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Super%20Seducer%202-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Super Seducer 2',
#     'locale': ''},
#    'viewers': 3803,
#    'channels': 6},
#   {'game': {'name': 'The Legend of Zelda: Ocarina of Time',
#     'popularity': 3650,
#     '_id': 11557,
#     'giantbomb_id': 12572,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/./The%20Legend%20of%20Zelda:%20Ocarina%20of%20Time-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'The Legend of Zelda: Ocarina of Time',
#     'locale': ''},
#    'viewers': 3627,
#    'channels': 31},
#   {'game': {'name': 'Monster Hunter World',
#     'popularity': 3627,
#     '_id': 497467,
#     'giantbomb_id': 59924,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Monster%20Hunter%20World-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Monster%20Hunter%20World-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Monster%20Hunter%20World-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Monster%20Hunter%20World-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Monster%20Hunter%20World-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Monster%20Hunter%20World-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Monster%20Hunter%20World-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Monster%20Hunter%20World-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Monster Hunter World',
#     'locale': ''},
#    'viewers': 3609,
#    'channels': 183},
#   {'game': {'name': 'ARK',
#     'popularity': 3429,
#     '_id': 489635,
#     'giantbomb_id': 49642,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/ARK-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/ARK-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/ARK-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/ARK-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/ARK-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/ARK-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/ARK-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/ARK-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'ARK',
#     'locale': ''},
#    'viewers': 3462,
#    'channels': 177},
#   {'game': {'name': 'Tabletop RPGs',
#     'popularity': 3512,
#     '_id': 509664,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Tabletop%20RPGs-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Tabletop%20RPGs-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Tabletop%20RPGs-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Tabletop%20RPGs-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Tabletop%20RPGs-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Tabletop%20RPGs-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Tabletop%20RPGs-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Tabletop%20RPGs-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Tabletop RPGs',
#     'locale': ''},
#    'viewers': 3329,
#    'channels': 3},
#   {'game': {'name': 'Marbles On Stream',
#     'popularity': 2576,
#     '_id': 509511,
#     'giantbomb_id': 0,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Marbles%20On%20Stream-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Marbles%20On%20Stream-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Marbles%20On%20Stream-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Marbles%20On%20Stream-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Marbles%20On%20Stream-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Marbles%20On%20Stream-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Marbles%20On%20Stream-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Marbles%20On%20Stream-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Marbles On Stream',
#     'locale': ''},
#    'viewers': 2934,
#    'channels': 66},
#   {'game': {'name': 'Visage',
#     'popularity': 2755,
#     '_id': 494082,
#     'giantbomb_id': 56806,
#     'box': {'large': 'https://static-cdn.jtvnw.net/ttv-boxart/Visage-272x380.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-boxart/Visage-136x190.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-boxart/Visage-52x72.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-boxart/Visage-{width}x{height}.jpg'},
#     'logo': {'large': 'https://static-cdn.jtvnw.net/ttv-logoart/Visage-240x144.jpg',
#      'medium': 'https://static-cdn.jtvnw.net/ttv-logoart/Visage-120x72.jpg',
#      'small': 'https://static-cdn.jtvnw.net/ttv-logoart/Visage-60x36.jpg',
#      'template': 'https://static-cdn.jtvnw.net/ttv-logoart/Visage-{width}x{height}.jpg'},
#     '_links': {},
#     'localized_name': 'Visage',
#     'locale': ''},
#    'viewers': 2877,
#    'channels': 47}]}
