# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from glob import glob

# %%
filenames = glob('../Games CSV/ Games Data*.csv')
dataframe_list = [pd.read_csv(f) for f in filenames]

# %%
all_data_df = pd.concat(dataframe_list)

# %%
all_data_df.head()
# Out:
#           Timestamp  Game Rank                      Game  Giantbomb ID  \
# 0  2018-10-04 21:27          1                  Fortnite         37030
# 1  2018-10-04 21:27          2         League of Legends         24024
# 2  2018-10-04 21:27          3          Sports & Fitness             0
# 3  2018-10-04 21:27          4             Just Chatting             0
# 4  2018-10-04 21:27          5  Assassin's Creed Odyssey         68771
#
#    Total Viewers  Total Channels
# 0         201354           15494
# 1          88663            2449
# 2          81293              19
# 3          57709             539
# 4          45258             346

# %%
all_data_by_game = all_data_df.sort_values(['Total Viewers','Game'], ascending=False)

# %%
all_data_by_game.head()
# Out:
#           Timestamp  Game Rank               Game  Giantbomb ID  \
# 0  2018-10-10 10:19          1  League of Legends         24024
# 0  2018-10-10 08:19          1  League of Legends         24024
# 0  2018-10-11 08:19          1  League of Legends         24024
# 0  2018-10-05 17:19          1           Fortnite         37030
# 0  2018-10-05 18:19          1           Fortnite         37030
#
#    Total Viewers  Total Channels
# 0         525265            1851
# 0         410365            1405
# 0         409008            1311
# 0         405749           15692
# 0         400185           15584

# %%
#Data Analysis
datagroup = all_data_df.groupby('Game')
data_means_df = datagroup.mean()
data_means_df.sort_values("Total Viewers", ascending=False)
# Out:
#                                       Game Rank  Giantbomb ID  Total Viewers  \
# Game
# Fortnite                               1.333333       37030.0  158288.388889
# League of Legends                      1.746032       24024.0  144432.111111
# Sports & Fitness                       3.000000           0.0   81293.000000
# Call of Duty: Black Ops 4              9.600000       66897.0   61316.466667
# Just Chatting                          4.658730           0.0   51420.714286
# Garry's Mod                            9.000000       20617.0   51376.333333
# ShellShock Live                       11.000000       49235.0   43882.000000
# Dota 2                                 6.349206       32887.0   42061.015873
# World of Warcraft                      6.325397       19783.0   39185.111111
# Assassin's Creed Odyssey               7.809524       68771.0   38453.277778
# PLAYERUNKNOWN'S BATTLEGROUNDS          7.523810       54979.0   37796.039683
# Counter-Strike: Global Offensive       8.746032       36113.0   33287.539683
# Rocket League                         10.480000       34407.0   32373.640000
# Hearthstone                            8.992063       42033.0   30391.912698
# BombTag                                9.000000       66442.0   29954.500000
# FIFA 19                               12.042017       68608.0   27252.848739
# Screencheat                            8.000000       47190.0   25002.000000
# Overwatch                             10.158730       48190.0   24997.888889
# Identity V                            12.000000       69347.0   24236.500000
# Barbie Horse Adventures: Riding Camp  13.000000       28403.0   23710.500000
# Special Events                        12.444444           0.0   23608.888889
# TrackMania² Stadium                   16.000000       40347.0   22148.000000
# Deliver Us The Moon                   15.750000       52325.0   21752.250000
# Jackbox Party Pack 5                  15.000000       69447.0   21628.000000
# Star Citizen                          17.000000       40011.0   20892.777778
# Casino                                13.041322           0.0   20649.338843
# StarCraft                             11.785714       13062.0   20351.642857
# Dungeons & Dragons                    12.333333           0.0   19991.333333
# Euro Truck Simulator 2                17.714286       40197.0   19402.428571
# EA Sports UFC 3                       14.714286       63209.0   19056.714286
# ...                                         ...           ...            ...
# Crazy Arcade                                1.500000
# Perception                                  1.250000
# Street Fighter V                           44.000000
# Wreckfest                                   6.000000
# Good Pizza, Great Pizza                     2.500000
# Marvel vs. Capcom Infinite                  1.250000
# ASMR                                       39.625000
# Dead Space                                 15.250000
# Monster Hunter World                      362.000000
# Superhot VR                                 1.000000
# Slay the Spire                             16.500000
# Silent Hill 2                               7.000000
# Dragalia Lost                              18.000000
# Sea of Thieves                             46.000000
# Oxygen Not Included                        14.000000
#
# [138 rows x 4 columns]

# %%
top_10_df = data_means_df.reset_index(level="Game")
top_10_df_sorted = top_10_df.sort_values("Total Viewers", ascending=False)
top_10_df_sorted.head(10)
# Out:
#                           Game  Game Rank  Giantbomb ID  Total Viewers  \
# 39                    Fortnite   1.333333       37030.0  158288.388889
# 57           League of Legends   1.746032       24024.0  144432.111111
# 104           Sports & Fitness   3.000000           0.0   81293.000000
# 12   Call of Duty: Black Ops 4   9.600000       66897.0   61316.466667
# 54               Just Chatting   4.658730           0.0   51420.714286
# 43                 Garry's Mod   9.000000       20617.0   51376.333333
# 95             ShellShock Live  11.000000       49235.0   43882.000000
# 27                      Dota 2   6.349206       32887.0   42061.015873
# 135          World of Warcraft   6.325397       19783.0   39185.111111
# 6     Assassin's Creed Odyssey   7.809524       68771.0   38453.277778
#
#      Total Channels
# 39      9988.642857
# 57      2107.587302
# 104       19.000000
# 12       392.866667
# 54       552.277778
# 43        44.333333
# 95         9.000000
# 27       596.960317
# 135     1243.119048
# 6        644.333333

# %%
newdataframe = top_10_df_sorted.loc[top_10_df_sorted["Total Viewers"] >= 34000, :]
newdataframe
# Out:
#                               Game  Game Rank  Giantbomb ID  Total Viewers  \
# 39                        Fortnite   1.333333       37030.0  158288.388889
# 57               League of Legends   1.746032       24024.0  144432.111111
# 104               Sports & Fitness   3.000000           0.0   81293.000000
# 12       Call of Duty: Black Ops 4   9.600000       66897.0   61316.466667
# 54                   Just Chatting   4.658730           0.0   51420.714286
# 43                     Garry's Mod   9.000000       20617.0   51376.333333
# 95                 ShellShock Live  11.000000       49235.0   43882.000000
# 27                          Dota 2   6.349206       32887.0   42061.015873
# 135              World of Warcraft   6.325397       19783.0   39185.111111
# 6         Assassin's Creed Odyssey   7.809524       68771.0   38453.277778
# 78   PLAYERUNKNOWN'S BATTLEGROUNDS   7.523810       54979.0   37796.039683
#
#      Total Channels
# 39      9988.642857
# 57      2107.587302
# 104       19.000000
# 12       392.866667
# 54       552.277778
# 43        44.333333
# 95         9.000000
# 27       596.960317
# 135     1243.119048
# 6        644.333333
# 78      1433.626984

# %%
x_axis = newdataframe["Total Viewers"]
labels = newdataframe["Game"]
colors = ["Purple","Plum","Pink","Orchid"]

# %%
games_viewer_average = newdataframe[["Game","Total Viewers"]]
games_viewer_average.to_csv("games_viewer_average.csv")

# %%
plt.pie(x_axis, labels=labels, startangle=0, colors=colors, shadow=True, autopct="%1.1f%%")
plt.title("Average Viewers per Game/Category")
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(9,9)
plt.savefig("Average Viewers per Game PieChart.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.savefig("Average Viewers per Game PieChart.png")
